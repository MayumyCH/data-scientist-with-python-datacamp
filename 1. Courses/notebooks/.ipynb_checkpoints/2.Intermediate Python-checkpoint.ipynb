# %% [markdown]
# **Prof: [Hugo Bowne Anderson](https://www.datacamp.com/instructors/hugobowne)**
#
# ---

# %% [markdown]
# # Matplotlib
# Madre de todas las visualizaciones de python

# %% [markdown]
# ### Basic plots with Matplotlib

# %%
import matplotlib.pyplot as plt

# %%
year =[1950, 1970, 1990, 2010]
pop =[2.519, 3.692, 5.263, 6.972]

# GRAFICO DE LINEAS
plt.plot(year,pop)
plt.show()

# %%
# GRAFICO DE DISPERSION
plt.scatter(year,pop)
# plt.xscale('log')
plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ### Histogram

# %% [markdown]
# Ayuda a tener una mejor distribucion de las variables

# %%
# help(plt.hist)

# %%
values = [0,0.6,1.4,1.6,2.2,2.5,2.6,3.2,3.5,3.9,4.2,6]
# plt.hist(values, bins=3)
plt.hist(values) # Por defecto se ponen bins = 10
plt.show()

# %% [markdown]
# > **NOTA** : Demasiados contenedores simplificarán demasiado la realidad y no le mostrarán los detalles.

# %% [markdown]
# **plt.show ()** muestra un gráfico;
#
# **plt.clf ()** lo limpia de nuevo para que pueda empezar de nuevo

# %% [markdown]
# ---

# %% [markdown]
# ### Customization

# %%
# Datos para el sgte item NO BORRAR !!
gdp_cap= [974.5803384,5937.029525999998,6223.367465, 4797.231267, 12779.37964, 34435.367439999995, 36126.4927, 29796.04834, 1391.253792, 33692.60508, 1441.284873, 3822.137084, 7446.298803, 12569.85177, 9065.800825, 10680.79282, 1217.032994, 430.0706916, 1713.778686, 2042.09524, 36319.23501, 706.016537, 1704.063724, 13171.63885, 4959.114854, 7006.580419, 986.1478792, 277.5518587, 3632.557798, 9645.06142, 1544.750112, 14619.222719999998, 8948.102923, 22833.30851, 35278.41874, 2082.4815670000007, 6025.3747520000015, 6873.262326000001, 5581.180998, 5728.353514, 12154.08975, 641.3695236000002, 690.8055759, 33207.0844, 30470.0167, 13206.48452, 752.7497265, 32170.37442, 1327.60891, 27538.41188, 5186.050003, 942.6542111, 579.2317429999998, 1201.637154, 3548.3308460000007, 39724.97867, 18008.94444, 36180.78919, 2452.210407, 3540.651564, 11605.71449, 4471.061906, 40675.99635, 25523.2771, 28569.7197, 7320.8802620000015, 31656.06806, 4519.461171, 1463.249282, 1593.06548, 23348.139730000006, 47306.98978, 10461.05868, 1569.331442, 414.5073415, 12057.49928, 1044.770126, 759.3499101, 12451.6558, 1042.581557, 1803.151496, 10956.99112, 11977.57496, 3095.7722710000007, 9253.896111, 3820.17523, 823.6856205, 944.0, 4811.060429, 1091.359778, 36797.93332, 25185.00911, 2749.320965, 619.6768923999998, 2013.977305, 49357.19017, 22316.19287, 2605.94758, 9809.185636, 4172.838464, 7408.905561, 3190.481016, 15389.924680000002, 20509.64777, 19328.70901, 7670.122558, 10808.47561, 863.0884639000002, 1598.435089, 21654.83194, 1712.472136, 9786.534714, 862.5407561000002, 47143.17964, 18678.31435, 25768.25759, 926.1410683, 9269.657808, 28821.0637, 3970.095407, 2602.394995, 4513.480643, 33859.74835, 37506.41907, 4184.548089, 28718.27684, 1107.482182, 7458.396326999998, 882.9699437999999, 18008.50924, 7092.923025, 8458.276384, 1056.380121, 33203.26128, 42951.65309, 10611.46299, 11415.80569, 2441.576404, 3025.349798, 2280.769906, 1271.211593, 469.70929810000007]
life_exp = [43.828, 76.423, 72.301, 42.731, 75.32, 81.235, 79.829, 75.635, 64.062, 79.441, 56.728, 65.554, 74.852, 50.728, 72.39, 73.005, 52.295, 49.58, 59.723, 50.43, 80.653, 44.74100000000001, 50.651, 78.553, 72.961, 72.889, 65.152, 46.462, 55.322, 78.782, 48.328, 75.748, 78.273, 76.486, 78.332, 54.791, 72.235, 74.994, 71.33800000000002, 71.878, 51.57899999999999, 58.04, 52.947, 79.313, 80.657, 56.735, 59.448, 79.406, 60.022, 79.483, 70.259, 56.007, 46.38800000000001, 60.916, 70.19800000000001, 82.208, 73.33800000000002, 81.757, 64.69800000000001, 70.65, 70.964, 59.545, 78.885, 80.745, 80.546, 72.567, 82.603, 72.535, 54.11, 67.297, 78.623, 77.58800000000002, 71.993, 42.592, 45.678, 73.952, 59.44300000000001, 48.303, 74.241, 54.467, 64.164, 72.801, 76.195, 66.803, 74.543, 71.164, 42.082, 62.069, 52.90600000000001, 63.785, 79.762, 80.204, 72.899, 56.867, 46.859, 80.196, 75.64, 65.483, 75.53699999999998, 71.752, 71.421, 71.688, 75.563, 78.098, 78.74600000000002, 76.442, 72.476, 46.242, 65.528, 72.777, 63.062, 74.002, 42.56800000000001, 79.972, 74.663, 77.926, 48.159, 49.339, 80.941, 72.396, 58.556, 39.613, 80.884, 81.70100000000002, 74.143, 78.4, 52.517, 70.616, 58.42, 69.819, 73.923, 71.777, 51.542, 79.425, 78.242, 76.384, 73.747, 74.249, 73.422, 62.698, 42.38399999999999, 43.487]
color =['red', 'green', 'blue', 'blue', 'yellow', 'black', 'green', 'red', 'red', 'green', 'blue', 'yellow', 'green', 'blue', 'yellow', 'green', 'blue', 'blue', 'red', 'blue', 'yellow', 'blue', 'blue', 'yellow', 'red', 'yellow', 'blue', 'blue', 'blue', 'yellow', 'blue', 'green', 'yellow', 'green', 'green', 'blue', 'yellow', 'yellow', 'blue', 'yellow', 'blue', 'blue', 'blue', 'green', 'green', 'blue', 'blue', 'green', 'blue', 'green', 'yellow', 'blue', 'blue', 'yellow', 'yellow', 'red', 'green', 'green', 'red', 'red', 'red', 'red', 'green', 'red', 'green', 'yellow', 'red', 'red', 'blue', 'red', 'red', 'red', 'red', 'blue', 'blue', 'blue', 'blue', 'blue', 'red', 'blue', 'blue', 'blue', 'yellow', 'red', 'green', 'blue', 'blue', 'red', 'blue', 'red', 'green', 'black', 'yellow', 'blue', 'blue', 'green', 'red', 'red', 'yellow', 'yellow', 'yellow', 'red', 'green', 'green', 'yellow', 'blue', 'green', 'blue', 'blue', 'red', 'blue', 'green', 'blue', 'red', 'green', 'green', 'blue', 'blue', 'green', 'red', 'blue', 'blue', 'green', 'green', 'red', 'red', 'blue', 'red', 'blue', 'yellow', 'blue', 'green', 'blue', 'green', 'yellow', 'yellow', 'yellow', 'red', 'red', 'red', 'blue', 'blue']
pop= [31.889923, 3.600523, 33.333216, 12.420476, 40.301927, 20.434176, 8.199783, 0.708573, 150.448339, 10.392226, 8.078314, 9.119152, 4.552198, 1.639131, 190.010647, 7.322858, 14.326203, 8.390505, 14.131858, 17.696293, 33.390141, 4.369038, 10.238807, 16.284741, 1318.683096, 44.22755, 0.71096, 64.606759, 3.80061, 4.133884, 18.013409, 4.493312, 11.416987, 10.228744, 5.46812, 0.496374, 9.319622, 13.75568, 80.264543, 6.939688, 0.551201, 4.906585, 76.511887, 5.23846, 61.083916, 1.454867, 1.688359, 82.400996, 22.873338, 10.70629, 12.572928, 9.947814, 1.472041, 8.502814, 7.483763, 6.980412, 9.956108, 0.301931, 1110.396331, 223.547, 69.45357, 27.499638, 4.109086, 6.426679, 58.147733, 2.780132, 127.467972, 6.053193, 35.610177, 23.301725, 49.04479, 2.505559, 3.921278, 2.012649, 3.193942, 6.036914, 19.167654, 13.327079, 24.821286, 12.031795, 3.270065, 1.250882, 108.700891, 2.874127, 0.684736, 33.757175, 19.951656, 47.76198, 2.05508, 28.90179, 16.570613, 4.115771, 5.675356, 12.894865, 135.031164, 4.627926, 3.204897, 169.270617, 3.242173, 6.667147, 28.674757, 91.077287, 38.518241, 10.642836, 3.942491, 0.798094, 22.276056, 8.860588, 0.199579, 27.601038, 12.267493, 10.150265, 6.144562, 4.553009, 5.447502, 2.009245, 9.118773, 43.997828, 40.448191, 20.378239, 42.292929, 1.133066, 9.031088, 7.554661, 19.314747, 23.174294, 38.13964, 65.068149, 5.701579, 1.056608, 10.276158, 71.158647, 29.170398, 60.776238, 301.139947, 3.447496, 26.084662, 85.262356, 4.018332, 22.211743, 11.746035, 12.311143]

# %%
import numpy as np

#plt.scatter(x: data positions(x), y: data positions(y), 
#            s:tamaño del marcador en puntos, alpha:nivel de opacidad ( (transparente) y 1 (opaco)))

# Scatter plot
plt.scatter(x = gdp_cap, y = life_exp, s = np.array(pop) * 2, c = color, alpha = 0.8)

# customizations scala
plt.xscale('log') 

# customizations labels and title
plt.xlabel('GDP per Capita [in USD]')
plt.ylabel('Life Expectancy [in years]')
plt.title('World Development in 2007')

# Definition of tick_val and tick_lab
tick_val = [1000, 10000, 100000]
tick_lab = ['1k', '10k', '100k']

# Adapt the ticks on the x-axis (Agregar marcas al eje X)
plt.xticks(tick_val,tick_lab)

# Additional customizations
plt.text(1550, 71, 'India')
plt.text(5700, 80, 'China')
plt.text(5800, 65, 'Mayu')

# Add grid() call
plt.grid(True)

# Show the plot
plt.show()

# %% [markdown]
# # Dictionaries & Pandas

# %% [markdown]
# ### Dictionaries, Part 1

# %%
world = {"afghanistan":30.55, "albania":2.77, "algeria":39.21}
world["albania"]
# Out:
# 2.77

# %% [markdown]
# ### Dictionaries, Part 2

# %%
world["sealand"] = 0.000027
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21, 'sealand': 2.7e-05}

# %%
"sealand" in world
# Out:
# True

# %%
del(world["sealand"])

# %%
world
# Out:
# {'afghanistan': 30.55, 'albania': 2.77, 'algeria': 39.21}

# %% [markdown]
# <img src="https://i.ibb.co/DKyc17n/Selecci-n-203.png" alt="Selecci-n-203" border="0">

# %% [markdown]
# ### Pandas, Part 1

# %% [markdown]
# Pandas es una herramienta de manipulación de datos de alto nivel desarrollada por wes McKInney, construida sobre el paquete Numpy

# %%
dict = { "country":["Brazil", "Russia", "India", "China", "South Africa"],
         "capital":["Brasilia", "Moscow", "New Delhi", "Beijing", "Pretoria"],
         "area":[8.516, 17.10, 3.286, 9.597, 1.221],
         "population":[200.4, 143.5, 1252, 1357, 52.98] }
dict
# Out:
# {'country': ['Brazil', 'Russia', 'India', 'China', 'South Africa'],
#  'capital': ['Brasilia', 'Moscow', 'New Delhi', 'Beijing', 'Pretoria'],
#  'area': [8.516, 17.1, 3.286, 9.597, 1.221],
#  'population': [200.4, 143.5, 1252, 1357, 52.98]}

# %%
import pandas as pd
brics = pd.DataFrame(dict)
brics
# Out:
#         country    capital    area  population
# 0        Brazil   Brasilia   8.516      200.40
# 1        Russia     Moscow  17.100      143.50
# 2         India  New Delhi   3.286     1252.00
# 3         China    Beijing   9.597     1357.00
# 4  South Africa   Pretoria   1.221       52.98

# %%
brics.index = ["BR", "RU", "IN", "CH", "SA"]
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %% [markdown]
# ***Importar datos desde un archivo externo*** que contiene los datos

# %%
# CSV = comma-separated values

brics = pd.read_csv("../datasets/brics.csv", index_col=0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
europe = { 'spain': { 'capital':'madrid', 'population':46.77 },
           'france': { 'capital':'paris', 'population':66.03 },
           'germany': { 'capital':'berlin', 'population':80.62 },
           'norway': { 'capital':'oslo', 'population':5.084 } }

# %%
# Capital de francia
europe['france']['capital']
# Out:
# 'paris'

# %% [markdown]
# ### Pandas, Part 2

# %%
brics["country"]
# Out:
# BR          Brazil
# RU          Russia
# IN           India
# CH           China
# SA    South Africa
# Name: country, dtype: object

# %%
type(brics["country"])
# Out:
# pandas.core.series.Series

# %%
brics[["country"]]
# Out:
#          country
# BR        Brazil
# RU        Russia
# IN         India
# CH         China
# SA  South Africa

# %%
type(brics[["country"]])
# Out:
# pandas.core.frame.DataFrame

# %%
# Obtener dos columnas
brics[["country",'capital']]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
# Obtener filas en especifico
brics[1:4]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %% [markdown]
# **TECNICAS PARA SELECCIONAR PARTES DE LOS DATOS**
#
# - **ILOC**: Tecnica basada en posicion (index)
# - **LOC**: Tecnica basada en etiquetas

# %%
brics.loc["RU"] # Pandas Series.
# Out:
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object

# %%
brics.loc[["RU"]] # Pandas DataFrame.
# Out:
#    country capital  area  population
# RU  Russia  Moscow  17.1       143.5

# %%
brics.loc[["RU","IN"]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0

# %%
brics.loc[["RU","IN"],["country","capital"]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi

# %%
brics.loc[:,["country","capital"]]
# Out:
#          country    capital
# BR        Brazil   Brasilia
# RU        Russia     Moscow
# IN         India  New Delhi
# CH         China    Beijing
# SA  South Africa   Pretoria

# %%
brics.iloc[[1,2,3]]
# Out:
#    country    capital    area  population
# RU  Russia     Moscow  17.100       143.5
# IN   India  New Delhi   3.286      1252.0
# CH   China    Beijing   9.597      1357.0

# %%
brics.iloc[[1,2,3],[0,1]]
# Out:
#    country    capital
# RU  Russia     Moscow
# IN   India  New Delhi
# CH   China    Beijing

# %% [markdown]
# # Logic, Control Flow and Filtering

# %% [markdown]
# ### Comparison Operators

# %%
"carl"<"chris"
# Out:
# True

# %% [markdown]
# - ### Boolean Operators

# %% [markdown]
#    ***Numpy***
#     - logical_and()
#     - logical_or()
#     - logical_not()

# %%
import numpy as np
height = [1.73, 1.68, 1.71, 1.89, 1.79] # lista
np_height = np.array(height) # Convirtiendo la lista en una matriz

weight = [65.4, 59.2, 63.6, 88.4, 68.7]
np_weight = np.array(weight)

bmi = np_weight / np_height**2
print(bmi)
# Out:
# [21.85171573 20.97505669 21.75028214 24.7473475  21.44127836]

# %%
np.logical_and(bmi>21,bmi<22 )
# Out:
# array([ True, False,  True, False,  True])

# %%
bmi[np.logical_and(bmi>21,bmi<22 )]
# Out:
# array([21.85171573, 21.75028214, 21.44127836])

# %% [markdown]
# ### if, elif, else

# %%
area = 10.0
if(area < 9) :
    print("small")
elif(area < 12) :
    print("medium")
else :
    print("large")
# Out:
# medium

# %% [markdown]
# ### Filtering pandas DataFrames

# %%
import pandas as pd
brics = pd.read_csv("../datasets/brics.csv", index_col=0)
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
# brics['area']
# brics.loc[:,'area']
brics.iloc[:,2]
# Out:
# BR     8.516
# RU    17.100
# IN     3.286
# CH     9.597
# SA     1.221
# Name: area, dtype: float64

# %%
brics['area'] > 8
# Out:
# BR     True
# RU     True
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
is_huge = brics['area'] > 8
is_huge
# Out:
# BR     True
# RU     True
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
brics[is_huge]
# Out:
#    country   capital    area  population
# BR  Brazil  Brasilia   8.516       200.4
# RU  Russia    Moscow  17.100       143.5
# CH   China   Beijing   9.597      1357.0

# %%
# LOGICAL CON PANDA
import numpy as np
np.logical_and(brics['area'] > 8,brics['area'] <10)
# Out:
# BR     True
# RU    False
# IN    False
# CH     True
# SA    False
# Name: area, dtype: bool

# %%
brics[np.logical_and(brics['area'] > 8,brics['area'] <10)]
# Out:
#    country   capital   area  population
# BR  Brazil  Brasilia  8.516       200.4
# CH   China   Beijing  9.597      1357.0

# %% [markdown]
# # Loops

# %% [markdown]
# - ### while loop

# %% [markdown]
# ```
# while condition:
#     expresion
# ```

# %%
error = 50.0
while error > 1 :
    error = error / 4
    print(error)
# Out:
# 12.5
# 3.125
# 0.78125

# %% [markdown]
# - ### for loop

# %%
fam = [1.73, 1.68, 1.71, 1.89]
for height in fam :    
    print(height)
# Out:
# 1.73
# 1.68
# 1.71
# 1.89

# %%
enumerate(fam)

# %%
fam = [1.73, 1.68, 1.71, 1.89]

for index, height in enumerate(fam) :    
    print("index " + str(index) + ": " + str(height))
# Out:
# index 0: 1.73
# index 1: 1.68
# index 2: 1.71
# index 3: 1.89

# %%
for c in "family" :
    print(c.capitalize())
# Out:
# F
# A
# M
# I
# L
# Y

# %% [markdown]
# ### Loop Data Structures Part 1

# %% [markdown]
# ```
# for var in seq :
#     expression
# ```
#
# ---

# %% [markdown]
# Si deseas iterar sobre clave - valor
#
# > **Dictionary** (metodo **items()**)
# - for key, val in my_dict.items() :
#
# > **Numpyarray 2D** (funcion **nditer**)
# - for val in np.nditer(my_array) :

# %%
world = { "afghanistan":30.55, "albania":2.77, "algeria":39.21 }

for key, value in world.items() :    
    print(key + " -- " + str(value))
# Out:
# afghanistan -- 30.55
# albania -- 2.77
# algeria -- 39.21

# %%
import numpy as np

np_height = np.array([1.73, 1.68, 1.71, 1.89, 1.79])
np_weight = np.array([65.4, 59.2, 63.6, 88.4, 68.7])

bmi = np_weight / np_height ** 2

for val in bmi :   
    print(val)
# Out:
# 21.85171572722109
# 20.97505668934241
# 21.750282138093777
# 24.74734749867025
# 21.44127836209856

# %%
meas = np.array([np_height, np_weight])
print(meas)
print("-----")
for val in meas:   
    print(val)
# Out:
# [[ 1.73  1.68  1.71  1.89  1.79]
#  [65.4  59.2  63.6  88.4  68.7 ]]
# -----
# [1.73 1.68 1.71 1.89 1.79]
# [65.4 59.2 63.6 88.4 68.7]

# %%
meas = np.array([np_height, np_weight])
for val in np.nditer(meas) :   
    print(val)
# Out:
# 1.73
# 1.68
# 1.71
# 1.89
# 1.79
# 65.4
# 59.2
# 63.6
# 88.4
# 68.7

# %% [markdown]
# ### Loop Data Structures Part 2

# %%
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
for lab, row in brics.iterrows():    
    print(lab) # Key
    print("------")
    print(row) # (Column - Value)
# Out:
# BR
# ------
# country         Brazil
# capital       Brasilia
# area             8.516
# population       200.4
# Name: BR, dtype: object
# RU
# ------
# country       Russia
# capital       Moscow
# area            17.1
# population     143.5
# Name: RU, dtype: object
# IN
# ------
# country           India
# capital       New Delhi
# area              3.286
# population         1252
# Name: IN, dtype: object
# CH
# ------
# country         China
# capital       Beijing
# area            9.597
# population       1357
# Name: CH, dtype: object
# SA
# ------
# country       South Africa
# capital           Pretoria
# area                 1.221
# population           52.98
# Name: SA, dtype: object

# %%
for lab, row in brics.iterrows():    
    print(lab + ": " + row["capital"])
# Out:
# BR: Brasilia
# RU: Moscow
# IN: New Delhi
# CH: Beijing
# SA: Pretoria

# %%
for lab, row in brics.iterrows() :
    # - Creating Series on every iteration    
    brics.loc[lab, "name_length"] = len(row["country"])
    
print(brics)
# Out:
#          country    capital    area  population  name_length
# BR        Brazil   Brasilia   8.516      200.40          6.0
# RU        Russia     Moscow  17.100      143.50          6.0
# IN         India  New Delhi   3.286     1252.00          5.0
# CH         China    Beijing   9.597     1357.00          5.0
# SA  South Africa   Pretoria   1.221       52.98         12.0

# %%
brics["name_length2"] = brics["country"].apply(len)
print(brics)
# Out:
#          country    capital    area  population  name_length  name_length2
# BR        Brazil   Brasilia   8.516      200.40          6.0             6
# RU        Russia     Moscow  17.100      143.50          6.0             6
# IN         India  New Delhi   3.286     1252.00          5.0             5
# CH         China    Beijing   9.597     1357.00          5.0             5
# SA  South Africa   Pretoria   1.221       52.98         12.0            12

# %%
brics["COUNTRY"] = brics["country"].apply(str.upper)
print(brics)
# Out:
#          country    capital    area  population  name_length  name_length2  \
# BR        Brazil   Brasilia   8.516      200.40          6.0             6
# RU        Russia     Moscow  17.100      143.50          6.0             6
# IN         India  New Delhi   3.286     1252.00          5.0             5
# CH         China    Beijing   9.597     1357.00          5.0             5
# SA  South Africa   Pretoria   1.221       52.98         12.0            12
#
#          COUNTRY
# BR        BRAZIL
# RU        RUSSIA
# IN         INDIA
# CH         CHINA
# SA  SOUTH AFRICA

# %% [markdown]
# ---

# %% [markdown]
# # Case Study: Hacker Statistics

# %% [markdown]
# Utilizará estadísticas para calcular sus posibilidades de ganar una apuesta.

# %% [markdown]
# ### Random Numbers

# %% [markdown]
# La aleatoriedad tiene muchos usos en ciencia, arte, estadística, criptografía, juegos, apuestas y otros campos. Usarás la aleatoriedad para simular un juego.
# Dos funciones del paquete numpy:
#
# - seed (): establece la semilla aleatoria, de modo que sus resultados sean reproducibles entre simulaciones.
# - rand (): si no especifica ningún argumento, genera un flotante aleatorio entre cero y uno

# %%
import numpy as np
np.random.rand() # Numero pseudoaleatorio
# Out:
# 0.025701768198283625

# %%
# Eligiendo nuestra VARIABLE SEMILLA
np.random.seed(123)
np.random.rand()
# Out:
# 0.6964691855978616

# %%
np.random.rand()
# Out:
# 0.28613933495037946

# %%
np.random.seed(123)
coin = np.random.randint(0,2)  # Randomly genera 0 or 1
print(coin)

if coin == 0:    
    print("heads")
else:    
    print("tails")
# Out:
# 0
# heads

# %%
np.random.seed(123)
print(np.random.randint(1, 7))
print(np.random.randint(1, 7))
# Out:
# 6
# 3

# %% [markdown]
# ### Random Walk

# %%
import numpy as np
np.random.seed(123)
outcomes = [] # resultados

for x in range(10) :    
    coin = np.random.randint(0, 2) # cara 0 || sello 1
    if coin == 0 :        
        outcomes.append("heads")
    else :        
        outcomes.append("tails")
print(outcomes)
# Out:
# ['heads', 'tails', 'heads', 'heads', 'heads', 'heads', 'heads', 'tails', 'tails', 'heads']

# %%
# Total de colas(sello) despues de lanzar 10 monedas (heads(cara) 0 || tails(sello) 1)
import numpy as np
np.random.seed(123)
tails = [0] # sello
for x in range(10) :    
    coin = np.random.randint(0, 2)    
    tails.append(tails[x] + coin)
    
print(tails)
# Out:
# [0, 0, 1, 1, 1, 1, 1, 1, 2, 3, 3]

# %%
# import numpy as np
np.random.randint(1,7)
# Out:
# 4

# %%
# Numpy is imported, seed is set
import numpy as np
np.random.seed(123)

# Initialization
random_walk = [0] # Caminata Aleatoria

for x in range(100) :
    step = random_walk[-1]
    dice = np.random.randint(1,7) # valores de 1 al 7

    if dice <= 2:
        step = max(0, step - 1)
    elif dice <= 5:
        step = step + 1
    else:
        step = step + np.random.randint(1,7)

    random_walk.append(step)

# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Plot random_walk
plt.plot(random_walk)

# Show the plot
plt.show()

# %% [markdown]
# ### Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt

np.random.seed(123)
final_tails = [] # Sello 
for x in range(1000) :
    tails = [0]
    for x in range(10) :    
        coin = np.random.randint(0, 2)    
        tails.append(tails[x] + coin)
    final_tails.append(tails[-1])

plt.hist(final_tails, bins=10)
plt.show()
# print(final_tails)

# %%
# numpy and matplotlib imported, seed set.

# import matplotlib.pyplot as plt
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(123)

# initialize and populate all_walks
all_walks = []

for i in range(10) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        random_walk.append(step)
    all_walks.append(random_walk)


# Convert all_walks to Numpy array: np_aw
np_aw = np.array(all_walks) 

# Plot np_aw and show
plt.plot(np_aw)
plt.show()

# Clear the figure
plt.clf()

# Transpose np_aw: np_aw_t
np_aw_t = np.transpose(np_aw)

# Plot np_aw_t and show
plt.plot(np_aw_t)
plt.show()

# %%
np.random.rand()
# Out:
# 0.5939023996740237

# %%
# ADD ERROR

# numpy and matplotlib imported, seed set
import numpy as np
np.random.seed(123)

# Simulate random walk 250 times
all_walks = []
for i in range(250) :
    random_walk = [0]
    
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)

        # Implementar clumsiness (Torpeza)
        clumsiness = np.random.rand() 
        if clumsiness < 0.001:
            step = 0

        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
plt.plot(np_aw_t)
plt.show()

# %%
brics
# Out:
#          country    capital    area  population
# BR        Brazil   Brasilia   8.516      200.40
# RU        Russia     Moscow  17.100      143.50
# IN         India  New Delhi   3.286     1252.00
# CH         China    Beijing   9.597     1357.00
# SA  South Africa   Pretoria   1.221       52.98

# %%
import numpy as np
np.random.seed(123)

# Simulate random walk 500 times
all_walks = []
for i in range(500) :
    random_walk = [0]
    for x in range(100) :
        step = random_walk[-1]
        dice = np.random.randint(1,7)
        if dice <= 2:
            step = max(0, step - 1)
        elif dice <= 5:
            step = step + 1
        else:
            step = step + np.random.randint(1,7)
        if np.random.rand() <= 0.001 :
            step = 0
        random_walk.append(step)
    all_walks.append(random_walk)

# Create and plot np_aw_t
np_aw_t = np.transpose(np.array(all_walks))
# print(np_aw_t)

# Seleccionar la ultima fila con todas sus columnas
ends= np_aw_t[-1,:]

# Plot histogram of ends, display plot
plt.hist(ends) 
plt.show()

# %%
# calcular el % de los que pasan el 60%
porc = ends[ends >= 60]
# 0.74
print(len(porc)/500)
# Out:
# 0.784
