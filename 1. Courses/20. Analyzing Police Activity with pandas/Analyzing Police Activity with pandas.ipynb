# %% [markdown]
# # Exploratory Data Analysis in Python

# %% [markdown]
# **Descripción del curso**
#
# Ahora que ha aprendido los fundamentos de los pandas, este curso le dará la oportunidad de aplicar ese conocimiento respondiendo preguntas interesantes sobre un conjunto de datos real. Explorará el conjunto de datos del Stanford Open Policing Project y analizará el impacto del género en el comportamiento de la policía. Durante el curso, obtendrá más práctica en la limpieza de datos desordenados, la creación de visualizaciones, la combinación y remodelación de conjuntos de datos y la manipulación de datos de series de tiempo. Analizar la actividad policial con pandas le brindará una valiosa experiencia analizando un conjunto de datos de principio a fin, ¡lo que lo preparará para su carrera en ciencia de datos!

# %% [markdown]
# Data completa en el sgte link:
# https://openpolicing.stanford.edu/

# %% [markdown]
# ## 1. Preparing the data for analysis

# %% [markdown]
# ### Stanford Open Policing Project dataset

# %%
import pandas as pd
trafic = pd.read_csv('https://raw.githubusercontent.com/MayumyCH/data-scientist-with-python-datacamp/main/datasets/20.%20Traffic_Rhode_Island.csv')
ri2 =pd.read_csv('https://raw.githubusercontent.com/MayumyCH/data-scientist-with-python-datacamp/main/datasets/20.%20Weather_Rhode_Island.csv')
trafic.head(3)
# Out:
#   state   stop_date stop_time  ...  stop_duration drugs_related_stop district
# 0    RI  2005-01-04     12:55  ...       0-15 Min              False  Zone X4
# 1    RI  2005-01-23     23:15  ...       0-15 Min              False  Zone K3
# 2    RI  2005-02-17     04:15  ...       0-15 Min              False  Zone X4
#
# [3 rows x 15 columns]

# %%
trafic.isnull().sum()
# Out:
# state                     0
# stop_date                 0
# stop_time                 0
# county_name           91741
# driver_gender          5205
# driver_race            5202
# violation_raw          5202
# violation              5202
# search_conducted          0
# search_type           88434
# stop_outcome           5202
# is_arrested            5202
# stop_duration          5202
# drugs_related_stop        0
# district                  0
# dtype: int64

# %%
trafic.shape
# Out:
# (91741, 15)

# %%
trafic.drop(['county_name', 'state'], axis='columns', inplace=True)

# %%
trafic.shape
# Out:
# (91741, 13)

# %%
# Elimine todas las filas que falten 'driver_gender' 
trafic.dropna(subset=['driver_gender'], inplace=True)

# %%
print(trafic.isnull().sum())
# Out:
# stop_date                 0
# stop_time                 0
# driver_gender             0
# driver_race               0
# violation_raw             0
# violation                 0
# search_conducted          0
# search_type           83229
# stop_outcome              0
# is_arrested               0
# stop_duration             0
# drugs_related_stop        0
# district                  0
# dtype: int64

# %%
print(trafic.shape)
# Out:
# (86536, 13)

# %% [markdown]
# ### Using proper data types

# %%
trafic.dtypes
# Out:
# stop_date             object
# stop_time             object
# driver_gender         object
# driver_race           object
# violation_raw         object
# violation             object
# search_conducted        bool
# search_type           object
# stop_outcome          object
# is_arrested           object
# stop_duration         object
# drugs_related_stop      bool
# district              object
# dtype: object

# %%
# Change the data type of 'is_arrested' to 'bool'
trafic['is_arrested'] = trafic.is_arrested.astype('bool')

# Check the data type of 'is_arrested' 
print(trafic.is_arrested.dtype)
# Out:
# bool

# %% [markdown]
# ### Creating a DatetimeIndex

# %%
trafic.head(2)
# Out:
#     stop_date stop_time  ... drugs_related_stop district
# 0  2005-01-04     12:55  ...              False  Zone X4
# 1  2005-01-23     23:15  ...              False  Zone K3
#
# [2 rows x 13 columns]

# %%
# trafic.date.str.replace('-','/')

# %%
# Concatenate 'stop_date' and 'stop_time' (separated by a space)
combined = trafic.stop_date.str.cat(trafic.stop_time,sep=" ")

# Convert 'combined' to datetime format
trafic['stop_datetime'] = pd.to_datetime(combined)

# Examine the data types of the DataFrame
print(trafic.dtypes)
# Out:
# stop_date                     object
# stop_time                     object
# driver_gender                 object
# driver_race                   object
# violation_raw                 object
# violation                     object
# search_conducted                bool
# search_type                   object
# stop_outcome                  object
# is_arrested                     bool
# stop_duration                 object
# drugs_related_stop              bool
# district                      object
# stop_datetime         datetime64[ns]
# dtype: object

# %%
# Set 'stop_datetime' as the index
trafic.set_index('stop_datetime', inplace=True)

# Examine the index
print(trafic.index)

# Examine the columns
print(trafic.columns)
# Out:
# DatetimeIndex(['2005-01-04 12:55:00', '2005-01-23 23:15:00',
#                '2005-02-17 04:15:00', '2005-02-20 17:15:00',
#                '2005-02-24 01:20:00', '2005-03-14 10:00:00',
#                '2005-03-29 21:55:00', '2005-04-04 21:25:00',
#                '2005-07-14 11:20:00', '2005-07-14 19:55:00',
#                ...
#                '2015-12-31 13:23:00', '2015-12-31 18:59:00',
#                '2015-12-31 19:13:00', '2015-12-31 20:20:00',
#                '2015-12-31 20:50:00', '2015-12-31 21:21:00',
#                '2015-12-31 21:59:00', '2015-12-31 22:04:00',
#                '2015-12-31 22:09:00', '2015-12-31 22:47:00'],
#               dtype='datetime64[ns]', name='stop_datetime', length=86536, freq=None)
# Index(['stop_date', 'stop_time', 'driver_gender', 'driver_race',
#        'violation_raw', 'violation', 'search_conducted', 'search_type',
#        'stop_outcome', 'is_arrested', 'stop_duration', 'drugs_related_stop',
#        'district'],
# ...

# %%
trafic.head(2)
# Out:
#                       stop_date stop_time  ... drugs_related_stop district
# stop_datetime                              ...
# 2005-01-04 12:55:00  2005-01-04     12:55  ...              False  Zone X4
# 2005-01-23 23:15:00  2005-01-23     23:15  ...              False  Zone K3
#
# [2 rows x 13 columns]

# %% [markdown]
# ## 2. Exploring the relationship between gender and policing

# %% [markdown]
# ### Do the genders commit different violations?

# %%
trafic.stop_outcome.value_counts()
# Out:
# Citation            77091
# Warning              5136
# Arrest Driver        2735
# No Action             624
# N/D                   607
# Arrest Passenger      343
# Name: stop_outcome, dtype: int64

# %%
77091/86536
# Out:
# 0.8908546731995932

# %%
trafic.stop_outcome.value_counts(normalize=True) # Hallar los porcentajes
# Out:
# Citation            0.890855
# Warning             0.059351
# Arrest Driver       0.031605
# No Action           0.007211
# N/D                 0.007014
# Arrest Passenger    0.003964
# Name: stop_outcome, dtype: float64

# %%
Warning = trafic[trafic.stop_outcome == 'Warning']
Warning.shape
# Out:
# (5136, 13)

# %%
# Create a DataFrame of female drivers
female = trafic[trafic.driver_gender == 'F']

# Create a DataFrame of male drivers
male = trafic[trafic.driver_gender == 'M']

# Compute the violations by female drivers (as proportions)
print(female.violation.value_counts(normalize=True))

# Compute the violations by male drivers (as proportions)
print(male.violation.value_counts(normalize=True))
# Out:
# Speeding               0.658114
# Moving violation       0.138218
# Equipment              0.105199
# Registration/plates    0.044418
# Other                  0.029738
# Seat belt              0.024312
# Name: violation, dtype: float64
# Speeding               0.522243
# Moving violation       0.206144
# Equipment              0.134158
# Other                  0.058985
# Registration/plates    0.042175
# Seat belt              0.036296
# Name: violation, dtype: float64

# %% [markdown]
# ### Does gender affect who gets a ticket for speeding?

# %%
female_arrested = trafic[(trafic.driver_gender == 'F') & (trafic.is_arrested == True)] # CONDICION "Y"
female_arrested.shape
# Out:
# (669, 13)

# %%
female_arrested2 = trafic[(trafic.driver_gender == 'F') | (trafic.is_arrested == True)] # CONDICION "O"
female_arrested2.shape
# Out:
# (26183, 13)

# %%
# Create a DataFrame of female drivers stopped for speeding
female_and_speeding = trafic[(trafic.driver_gender == 'F') & (trafic.violation == "Speeding")]

# Create a DataFrame of male drivers stopped for speeding
male_and_speeding = trafic[(trafic.driver_gender == 'M') & (trafic.violation == "Speeding")]

# Compute the stop outcomes for female drivers (as proportions)
print(female_and_speeding.stop_outcome.value_counts(normalize=True))

# Compute the stop outcomes for male drivers (as proportions)
print(male_and_speeding.stop_outcome.value_counts(normalize=True))
# Out:
# Citation            0.952192
# Warning             0.040074
# Arrest Driver       0.005752
# N/D                 0.000959
# Arrest Passenger    0.000639
# No Action           0.000383
# Name: stop_outcome, dtype: float64
# Citation            0.944595
# Warning             0.036184
# Arrest Driver       0.015895
# Arrest Passenger    0.001281
# No Action           0.001068
# N/D                 0.000976
# Name: stop_outcome, dtype: float64

# %% [markdown]
# ### Does gender affect whose vehicle is searched?

# %%
# Check the data type of 'search_conducted'
print(trafic.search_conducted.dtype)

# Calculate the search rate by counting the values
print(trafic.search_conducted.value_counts(normalize=True))

# Calculate the search rate by taking the mean
print(trafic.search_conducted.mean())
# Out:
# bool
# False    0.961785
# True     0.038215
# Name: search_conducted, dtype: float64
# 0.0382153092354627

# %%
trafic.head(2)
# Out:
#                       stop_date stop_time  ... drugs_related_stop district
# stop_datetime                              ...
# 2005-01-04 12:55:00  2005-01-04     12:55  ...              False  Zone X4
# 2005-01-23 23:15:00  2005-01-23     23:15  ...              False  Zone K3
#
# [2 rows x 13 columns]

# %%
# Calculate the search rate for female drivers
print(trafic[trafic.driver_gender == 'F'].search_conducted.mean())
# Out:
# 0.019180617481282074

# %%
# Calculate the search rate for both groups simultaneously
print(trafic.groupby('driver_gender').search_conducted.mean())
# Out:
# driver_gender
# F    0.019181
# M    0.045426
# Name: search_conducted, dtype: float64

# %%
# Calculate the search rate for each combination of gender and violation
print(trafic.groupby(['driver_gender','violation']).search_conducted.mean())
# Out:
# driver_gender  violation
# F              Equipment              0.039984
#                Moving violation       0.039257
#                Other                  0.041018
#                Registration/plates    0.054924
#                Seat belt              0.017301
#                Speeding               0.008309
# M              Equipment              0.071496
#                Moving violation       0.061524
#                Other                  0.046191
#                Registration/plates    0.108802
#                Seat belt              0.035119
#                Speeding               0.027885
# Name: search_conducted, dtype: float64

# %%
# Reverse the ordering to group by violation before gender
print(trafic.groupby(['violation','driver_gender']).search_conducted.mean())
# Out:
# violation            driver_gender
# Equipment            F                0.039984
#                      M                0.071496
# Moving violation     F                0.039257
#                      M                0.061524
# Other                F                0.041018
#                      M                0.046191
# Registration/plates  F                0.054924
#                      M                0.108802
# Seat belt            F                0.017301
#                      M                0.035119
# Speeding             F                0.008309
#                      M                0.027885
# Name: search_conducted, dtype: float64

# %% [markdown]
# ### Does gender affect who is frisked during a search?

# %%
# Count the 'search_type' values
print(trafic.search_type.value_counts())

# Check if 'search_type' contains the string 'Protective Frisk'
trafic['frisk'] = trafic.search_type.str.contains('Protective Frisk', na=False)

# Check the data type of 'frisk'
print(trafic.frisk.dtype)

# Take the sum of 'frisk'
print(trafic.frisk.sum())
# Out:
# Incident to Arrest                                          1290
# Probable Cause                                               924
# Inventory                                                    219
# Reasonable Suspicion                                         214
# Protective Frisk                                             164
# Incident to Arrest,Inventory                                 123
# Incident to Arrest,Probable Cause                            100
# Probable Cause,Reasonable Suspicion                           54
# Incident to Arrest,Inventory,Probable Cause                   35
# Probable Cause,Protective Frisk                               35
# Incident to Arrest,Protective Frisk                           33
# Inventory,Probable Cause                                      25
# Protective Frisk,Reasonable Suspicion                         19
# Incident to Arrest,Inventory,Protective Frisk                 18
# ...

# %%
# Create a DataFrame of stops in which a search was conducted
searched = trafic[trafic.search_conducted == True]

# Calculate the overall frisk rate by taking the mean of 'frisk'
print(searched.frisk.mean())

# Calculate the frisk rate for each gender
print(searched.groupby('driver_gender').frisk.mean())
# Out:
# 0.09162382824312065
# driver_gender
# F    0.074561
# M    0.094353
# Name: frisk, dtype: float64

# %% [markdown]
# ## 3. Visual exploratory data analysis

# %% [markdown]
# ### Does time of day affect arrest rate?

# %%
trafic.head(2)
# Out:
#                       stop_date stop_time  ... district  frisk
# stop_datetime                              ...
# 2005-01-04 12:55:00  2005-01-04     12:55  ...  Zone X4  False
# 2005-01-23 23:15:00  2005-01-23     23:15  ...  Zone K3  False
#
# [2 rows x 14 columns]

# %%
# Calculate the overall arrest rate
print(trafic.is_arrested.mean())

# Calculate the hourly arrest rate
print(trafic.groupby(trafic.index.hour).is_arrested.mean())

# Save the hourly arrest rate
hourly_arrest_rate = trafic.groupby(trafic.index.hour).is_arrested.mean()
# Out:
# 0.0355690117407784
# stop_datetime
# 0     0.051431
# 1     0.064932
# 2     0.060798
# 3     0.060549
# 4     0.048000
# 5     0.042781
# 6     0.013813
# 7     0.013032
# 8     0.021854
# 9     0.025206
# 10    0.028213
# 11    0.028897
# 12    0.037399
# 13    0.030776
# 14    0.030605
# 15    0.030679
# 16    0.035281
# 17    0.040619
# 18    0.038204
# 19    0.032245
# 20    0.038107
# 21    0.064541
# 22    0.048666
# 23    0.047592
# Name: is_arrested, dtype: float64

# %%
# Import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# Create a line plot of 'hourly_arrest_rate'
hourly_arrest_rate.plot()

# Add the xlabel, ylabel, and title
plt.xlabel('Hour')
plt.ylabel('Arrest Rate')
plt.title('Arrest Rate by Time of Day')

# Display the plot
plt.show()

# %% [markdown]
# ### Are drug-related stops on the rise?

# %%
# Calculate the annual rate of drug-related stops
print(trafic.drugs_related_stop.resample('A').mean())

# Save the annual rate of drug-related stops
annual_drug_rate = trafic.drugs_related_stop.resample('A').mean()

# Create a line plot of 'annual_drug_rate'
annual_drug_rate.plot()

# Display the plot
plt.show()
# Out:
# stop_datetime
# 2005-12-31    0.006501
# 2006-12-31    0.007258
# 2007-12-31    0.007970
# 2008-12-31    0.007505
# 2009-12-31    0.009889
# 2010-12-31    0.010081
# 2011-12-31    0.009731
# 2012-12-31    0.009921
# 2013-12-31    0.013094
# 2014-12-31    0.013826
# 2015-12-31    0.012266
# Freq: A-DEC, Name: drugs_related_stop, dtype: float64

# %%
# Calculate and save the annual search rate
annual_search_rate = trafic.search_conducted.resample('A').mean()

# Concatenate 'annual_drug_rate' and 'annual_search_rate'
annual = pd.concat([annual_drug_rate,annual_search_rate], axis='columns')

# Create subplots from 'annual'
annual.plot(subplots=True)

# Display the subplots
plt.show()

# %% [markdown]
# #### What violations are caught in each district?

# %%
# Create a frequency table of districts and violations
print(pd.crosstab(trafic.district,trafic.violation))

# Save the frequency table as 'all_zones'
all_zones = pd.crosstab(trafic.district,trafic.violation)

# Select rows 'Zone K1' through 'Zone K3'
print(all_zones.loc['Zone K1':'Zone K3'])

# Save the smaller table as 'k_zones'
k_zones = all_zones.loc['Zone K1':'Zone K3']
# Out:
# violation  Equipment  Moving violation  ...  Seat belt  Speeding
# district                                ...
# Zone K1          672              1254  ...          0      5960
# Zone K2         2061              2962  ...        481     10448
# Zone K3         2302              2898  ...        638     12322
# Zone X1          296               671  ...         74      1119
# Zone X3         2049              3086  ...        820      8779
# Zone X4         3541              5353  ...        843      9795
#
# [6 rows x 6 columns]
# violation  Equipment  Moving violation  ...  Seat belt  Speeding
# district                                ...
# Zone K1          672              1254  ...          0      5960
# Zone K2         2061              2962  ...        481     10448
# Zone K3         2302              2898  ...        638     12322
#
# [3 rows x 6 columns]

# %%
# Create a bar plot of 'k_zones'
k_zones.plot(kind="bar")

# Display the plot
plt.show()

# %%
# Create a stacked bar plot of 'k_zones'
k_zones.plot(kind="bar",stacked=True)

# Display the plot
plt.show()

# %% [markdown]
# #### How long might you be stopped for a violation?

# %%
# Print the unique values in 'stop_duration'
print(trafic.stop_duration.unique())

# Create a dictionary that maps strings to integers
mapping = {'0-15 Min':8,'16-30 Min':23,'30+ Min':45}

# Convert the 'stop_duration' strings to integers using the 'mapping'
trafic['stop_minutes'] = trafic.stop_duration.map(mapping)

# Print the unique values in 'stop_minutes'
print(trafic.stop_minutes.unique())
# Out:
# ['0-15 Min' '16-30 Min' '30+ Min']
# [ 8 23 45]

# %%
# Calculate the mean 'stop_minutes' for each value in 'violation_raw'
print(trafic.groupby('violation_raw').stop_minutes.mean())

# Save the resulting Series as 'stop_length'
stop_length = trafic.groupby('violation_raw').stop_minutes.mean()

# Sort 'stop_length' by its values and create a horizontal bar plot
stop_length.sort_values().plot(kind='barh')

# Display the plot
plt.show()
# Out:
# violation_raw
# APB                                 17.967033
# Call for Service                    22.124371
# Equipment/Inspection Violation      11.445655
# Motorist Assist/Courtesy            17.741463
# Other Traffic Violation             13.844490
# Registration Violation              13.736970
# Seatbelt Violation                   9.662815
# Special Detail/Directed Patrol      15.123632
# Speeding                            10.581562
# Suspicious Person                   14.910714
# Violation of City/Town Ordinance    13.254144
# Warrant                             24.055556
# Name: stop_minutes, dtype: float64

# %% [markdown]
# ## 4. Analyzing the effect of weather on policing

# %% [markdown]
# ### Exploring the weather dataset

# %%
# Read 'weather.csv' into a DataFrame named 'weather'
# weather = pd.read_csv('weather.csv')
url_data = 'https://raw.githubusercontent.com/MayumyCH/data-scientist-with-python-datacamp/main/datasets/20.%20Weather_Rhode_Island.csv'
weather = pd.read_csv(url_data)

# Describe the temperature columns
print(weather[['TMIN','TAVG','TMAX']].describe())

# Create a box plot of the temperature columns
weather[['TMIN','TAVG','TMAX']].plot(kind='box')

# Display the plot
plt.show()
# Out:
#               TMIN         TAVG         TMAX
# count  4017.000000  1217.000000  4017.000000
# mean     43.484441    52.493016    61.268608
# std      17.020298    17.830714    18.199517
# min      -5.000000     6.000000    15.000000
# 25%      30.000000    39.000000    47.000000
# 50%      44.000000    54.000000    62.000000
# 75%      58.000000    68.000000    77.000000
# max      77.000000    86.000000   102.000000
# /usr/local/lib/python3.7/dist-packages/numpy/core/_asarray.py:83: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray
#   return array(a, dtype, copy=False, order=order)

# %%
# Create a 'TDIFF' column that represents temperature difference
weather['TDIFF'] = weather.TMAX - weather.TMIN

# Describe the 'TDIFF' column
print(weather.TDIFF.describe())

# Create a histogram with 20 bins to visualize 'TDIFF'
weather.TDIFF.plot(kind = 'hist', bins = 20)

# Display the plot
plt.show()
# Out:
# count    4017.000000
# mean       17.784167
# std         6.350720
# min         2.000000
# 25%        14.000000
# 50%        18.000000
# 75%        22.000000
# max        43.000000
# Name: TDIFF, dtype: float64

# %% [markdown]
# ### Categorizing the weather

# %%
# Copy 'WT01' through 'WT22' to a new DataFrame
WT = weather.loc[:,'WT01':'WT22']

# Calculate the sum of each row in 'WT'
weather['bad_conditions'] = WT.sum(axis='columns')

# Replace missing values in 'bad_conditions' with '0'
weather['bad_conditions'] = weather.bad_conditions.fillna(0).astype('int')

# Create a histogram to visualize 'bad_conditions'
weather['bad_conditions'].plot(kind = 'hist')

# Display the plot
plt.show()

# %%
# Count the unique values in 'bad_conditions' and sort the index
print(weather.bad_conditions.value_counts().sort_index())

# Create a dictionary that maps integers to strings
mapping = {0:'good', 1:'bad', 2:'bad', 3:'bad', 4:'bad', 5:'worse', 6:'worse', 7:'worse', 8:'worse', 9:'worse'}

# Convert the 'bad_conditions' integers to strings using the 'mapping'
weather['rating'] = weather.bad_conditions.map(mapping)

# Count the unique values in 'rating'
print(weather.rating.value_counts())
# Out:
# 0    1749
# 1     613
# 2     367
# 3     380
# 4     476
# 5     282
# 6     101
# 7      41
# 8       4
# 9       4
# Name: bad_conditions, dtype: int64
# bad      1836
# good     1749
# worse     432
# Name: rating, dtype: int64

# %%
weather['rating'].head(3)
# Out:
# 0    bad
# 1    bad
# 2    bad
# Name: rating, dtype: object

# %%
# Create a list of weather ratings in logical order
cats = ['good', 'bad', 'worse']

# Change the data type of 'rating' to category
# weather['rating'] = weather['rating'].astype('category', categories = cats, ordered = True) #ANTIGUO ---
weather['rating']= pd.Categorical(weather['rating'], categories=cats, ordered=True) #NUEVA VERSION

# Examine the head of 'rating'
print(weather.rating.head())
# Out:
# 0    bad
# 1    bad
# 2    bad
# 3    bad
# 4    bad
# Name: rating, dtype: category
# Categories (3, object): ['good' < 'bad' < 'worse']

# %% [markdown]
# ### Merging datasets

# %%
# Reset the index of 'ri'
trafic.reset_index(inplace=True)

# Examine the head of 'ri'
print(trafic.head())

# Create a DataFrame from the 'DATE' and 'rating' columns
weather_rating = weather[['DATE','rating']]

# Examine the head of 'weather_rating'
print(weather_rating.head())
# Out:
#         stop_datetime   stop_date stop_time  ... district  frisk stop_minutes
# 0 2005-01-04 12:55:00  2005-01-04     12:55  ...  Zone X4  False            8
# 1 2005-01-23 23:15:00  2005-01-23     23:15  ...  Zone K3  False            8
# 2 2005-02-17 04:15:00  2005-02-17     04:15  ...  Zone X4  False            8
# 3 2005-02-20 17:15:00  2005-02-20     17:15  ...  Zone X1  False           23
# 4 2005-02-24 01:20:00  2005-02-24     01:20  ...  Zone X3  False            8
#
# [5 rows x 16 columns]
#          DATE rating
# 0  2005-01-01    bad
# 1  2005-01-02    bad
# 2  2005-01-03    bad
# 3  2005-01-04    bad
# 4  2005-01-05    bad

# %%
# Examine the shape of 'ri'
print(trafic.shape)

# Merge 'ri' and 'weather_rating' using a left join
ri_weather = pd.merge(left=trafic, right=weather_rating, left_on='stop_date', right_on='DATE', how='left')

# Examine the shape of 'ri_weather'
print(ri_weather.shape)

# Set 'stop_datetime' as the index of 'ri_weather'
ri_weather.set_index('stop_datetime', inplace=True)

# ri_weather.head(3)
# Out:
# (86536, 16)
# (86536, 18)

# %% [markdown]
# ### Does weather affect the arrest rate?

# %%
# TRABAJAR LA DATA CON SERIES DE MULTIINDICE
# Calculate the overall arrest rate
print(ri_weather.is_arrested.mean())
# Calculate the arrest rate for each 'rating'
print(ri_weather.groupby('rating').is_arrested.mean())
# Calculate the arrest rate for each 'violation' and 'rating'
print(ri_weather.groupby(['violation','rating']).is_arrested.mean())
# Out:
# 0.0355690117407784
# rating
# good     0.033715
# bad      0.036261
# worse    0.041667
# Name: is_arrested, dtype: float64
# violation            rating
# Equipment            good      0.059007
#                      bad       0.066311
#                      worse     0.097357
# Moving violation     good      0.056227
#                      bad       0.058050
#                      worse     0.065860
# Other                good      0.076966
#                      bad       0.087443
#                      worse     0.062893
# Registration/plates  good      0.081574
#                      bad       0.098160
#                      worse     0.115625
# Seat belt            good      0.028587
#                      bad       0.022493
#                      worse     0.000000
# Speeding             good      0.013405
#                      bad       0.013314
#                      worse     0.016886
# Name: is_arrested, dtype: float64

# %% [markdown]
# ¡Guau! La tasa de arrestos aumenta a medida que empeora el clima y esa tendencia persiste en muchos de los tipos de infracción.
# Esto no prueba un vínculo causal, ¡pero es un resultado bastante interesante!

# %%
# Save the output of the groupby operation from the last exercise
arrest_rate = ri_weather.groupby(['violation', 'rating']).is_arrested.mean()

# Print the 'arrest_rate' Series
print(arrest_rate)

# Print the arrest rate for moving violations in bad weather
print(arrest_rate.loc['Moving violation','bad'])

# Print the arrest rates for speeding violations in all three weather conditions
print(arrest_rate.loc['Speeding'])
# Out:
# violation            rating
# Equipment            good      0.059007
#                      bad       0.066311
#                      worse     0.097357
# Moving violation     good      0.056227
#                      bad       0.058050
#                      worse     0.065860
# Other                good      0.076966
#                      bad       0.087443
#                      worse     0.062893
# Registration/plates  good      0.081574
#                      bad       0.098160
#                      worse     0.115625
# Seat belt            good      0.028587
#                      bad       0.022493
#                      worse     0.000000
# Speeding             good      0.013405
#                      bad       0.013314
#                      worse     0.016886
# Name: is_arrested, dtype: float64
# 0.05804964058049641
# rating
# good     0.013405
# bad      0.013314
# worse    0.016886
# Name: is_arrested, dtype: float64

# %%
print(arrest_rate)
# Out:
# violation            rating
# Equipment            good      0.059007
#                      bad       0.066311
#                      worse     0.097357
# Moving violation     good      0.056227
#                      bad       0.058050
#                      worse     0.065860
# Other                good      0.076966
#                      bad       0.087443
#                      worse     0.062893
# Registration/plates  good      0.081574
#                      bad       0.098160
#                      worse     0.115625
# Seat belt            good      0.028587
#                      bad       0.022493
#                      worse     0.000000
# Speeding             good      0.013405
#                      bad       0.013314
#                      worse     0.016886
# Name: is_arrested, dtype: float64

# %%
# Unstack the 'arrest_rate' Series into a DataFrame
print(arrest_rate.unstack())


# DE SERIE MULTIINDICE A DATAFRAME -----------------
# Out:
# rating                   good       bad     worse
# violation
# Equipment            0.059007  0.066311  0.097357
# Moving violation     0.056227  0.058050  0.065860
# Other                0.076966  0.087443  0.062893
# Registration/plates  0.081574  0.098160  0.115625
# Seat belt            0.028587  0.022493  0.000000
# Speeding             0.013405  0.013314  0.016886

# %%
# Create the same DataFrame using a pivot table
print(ri_weather.pivot_table(index='violation', columns='rating', values='is_arrested'))
# Out:
# rating                   good       bad     worse
# violation
# Equipment            0.059007  0.066311  0.097357
# Moving violation     0.056227  0.058050  0.065860
# Other                0.076966  0.087443  0.062893
# Registration/plates  0.081574  0.098160  0.115625
# Seat belt            0.028587  0.022493  0.000000
# Speeding             0.013405  0.013314  0.016886
