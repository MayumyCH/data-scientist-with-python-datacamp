# %% [markdown]
# ```
# Level Alcanzado: INTERMEDIO || Score: 115 || Percentile: 69% || Fecha: 01/12/2020
# ```
#
# ```
# Level Alcanzado: AVANZADO || Score: 138 || Percentile: 90% || Fecha: 02/04/2021
# ```
#
# ```
# Level Alcanzado: AVANZADO || Score: 87 || Percentile: 33% || Fecha: 02/04/2021
# ```
#
# ```
# Level Alcanzado: INTERMEDIO || Score: 123 || Percentile: 78% || Fecha: 02/04/2021
# ```
# ---

# %%
def count_words(filename):
  """Count the number of words in a file"""
  try:
    with open(filename, encoding='utf-8') as f:
      contents = f.read()
  except FileNotFoundError:
    print("The file {} cannot be found".format(filename))
  else:
    words = contents.split()
    num_words = len(words)
    print("The file {} has about {} words.".format(filename, num_words))
    
filename = "peter_rabbit.txt"
count_words(filename)
# Out:
# The file peter_rabbit.txt cannot be found

# %%
def sample(n):
    x = []
    for i in range(n):
        x.append(random.random())
    return x

# %%
import random
random.seed(2427)

def efficient_sample(n):
  x = [random.random() for i in range(n)]
  return x

efficient_sample(20)

# %%
def make_dict(**kwargs):
    return kwargs
make_dict(a = 1, b = 2)
# Out:
# {'a': 1, 'b': 2}

# %%
def factorial(n):
    """returns n!"""
    return 1 if n < 2 else n * factorial(n-1)

factorial.__doc__
# help(factorial)
# Out:
# 'returns n!'

# %%
def multiply(a, b):
    """documentacion de la funcion!"""
    return a * b
x = multiply(3, 4)
print(x)
print(multiply.__doc__)
# Out:
# 12
# documentacion de la funcion!

# %%
# Cree una clase llamada Planet que tenga un atributo name 
# y diameter_km que debe establecerse cuando se crea un nuevo objeto.
class Planet:
    def __init__(self, name, diameter_km):
        self.name = name
        self.diameter_km = diameter_km

    def woof(self):
        return 'woof!'
        
e = Planet("Earth", 12742)
print(e.name, e.diameter_km)
print(e.woof())
# Out:
# Earth 12742
# woof!

# %%
class Dog:
    def __init__(self):
        pass
    
    def bark(self,name):
        return "bark bark bark bark..." , name

d = Dog()
d.bark("Pepe")
# Out:
# ('bark bark bark bark...', 'Pepe')

# %%
dict_gen = { i:i for i in range(5) }
dict_gen
# Out:
# {0: 0, 1: 1, 2: 2, 3: 3, 4: 4}

# %%
my_dict = { num: num ** 2 for num in range(6) if num%2 == 0 }
my_dict
# Out:
# {0: 0, 2: 4, 4: 16}

# %%
book = {
    'title': 'The Giver',
    'author': 'Lois Lowry',
    'rating': 4.13
}

book['rating']=4.6
print(book['rating'])
print(type(book))
# Out:
# 4.6
# <class 'dict'>

# %%
[i * 3 for i in range(5)]
# Out:
# [0, 3, 6, 9, 12]

# %%
for num in range(5) :
  print(num)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
packages = ["numpy", "pandas", "scipy"]
for i in packages:
    print(i)
# Out:
# numpy
# pandas
# scipy

# %%
vals = [25, 30, 33, 35, 40, 180]
new_vals = []
for val in vals:
    new_vals.append(val + 32)
print(new_vals)
# Out:
# [57, 62, 65, 67, 72, 212]

# %%
a = [i for i in range(5) if i>=3]
a
# Out:
# [3, 4]

# %%
a = [i * 2 for i in range(5)]
a
# Out:
# [0, 2, 4, 6, 8]

# %%
import random
random.seed(2427)
a =[random.random() for i in range(3)]
a
# Out:
# [0.6709313964859867, 0.9738115340563225, 0.6064264401595373]

# %%
vals = [25, 30, 33, 35, 40, 180]
new_vals = [i + 32 for i in vals]
print(new_vals)
# Out:
# [57, 62, 65, 67, 72, 212]

# %%
x = ['a', 'b', 'c']
y = enumerate(x)
print(y)
print(list(y))
# Out:
# ...
# [(0, 'a'), (1, 'b'), (2, 'c')]

# %%
letters = ['a', 'b', 'c']
for ii, x in enumerate(letters): #INDICE-LETRA
    print(ii, ": ", x)
# Out:
# 0 :  a
# 1 :  b
# 2 :  c

# %%
numbers = [9, 2, 5, 11, 4, 3]
smallest = min(numbers)
print(smallest)
# Out:
# 2

# %%
numbers = [9, 2, 5, 11, 4, 3]
maxxx = max(numbers)
print(maxxx)
# Out:
# 11

# %%
s = "animal-horse"
s.split("-")
# Out:
# ['animal', 'horse']

# %%
a = ("a", "b", "c", "d", "e", "f", "g", "h")
x = slice(3, 5)
# print(x)
print(a[x])
# Out:
# slice(3, 5, None)
# ('d', 'e')

# %%
a = {1, 2, 3, 4}
b = {3, 4, 5, 6}

print(a.intersection(b))
print(a.union(b))
print(a.difference(b))
# Out:
# {3, 4}
# {1, 2, 3, 4, 5, 6}
# {1, 2}

# %%
w = 'python'
w_iterator = iter(w)
next(w_iterator)
# Out:
# 'p'

# %%
s = "fox"
s.rjust(20)
s
# Out:
# 'fox'

# %%
txt = "fox"
# x = txt.rjust(20, "O")
x = txt.rjust(20)
print(x, "--")
# Out:
#                  fox --

# %%
x = lambda : "I know how to call this function."
x()
# Out:
# 'I know how to call this function.'

# %%
f = lambda x,y: x * y
f(4,2)
# Out:
# 8

# %%
# [i for i in range(5) if i >2 and i<5]
[i for i in range(5) if i > 2]
# Out:
# [3, 4]

# %%
A = [i.upper() for i in ['hello', 'world']]
A
# Out:
# ['HELLO', 'WORLD']

# %%
ints = set([1,1,2,3,3,3,4]) # Crear un conjunto
print(ints)
print(len(ints))
# Out:
# {1, 2, 3, 4}
# 4

# %%
# x = {"red", "green", "blue"}
x = (1, 2, 3)
s = set(x)
s
# Out:
# {1, 2, 3}

# %%
boardgames = [
  'Pandemic Legacy: Season 1', 
  'Terraforming Mars', 
]
boardgames.insert(0, 'Gloomhaven')
print(boardgames)
# Out:
# ['Gloomhaven', 'Pandemic Legacy: Season 1', 'Terraforming Mars']
